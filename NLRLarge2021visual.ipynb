# %% [markdown]
# ### NRL Large Dataset
# ### June 2021

# %%
import scipy.io
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline
mat = scipy.io.loadmat('C:/Users/eacun/Downloads/dataset55_release2.mat')

# %%
mat.items()
# Out:
# dict_items([('__header__', b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jul 22 14:13:11 2020'), ('__version__', '1.0'), ('__globals__', []), ('addedNoisePercent', array([[0.1],
#        [0.5],
#        [0. ],
#        ...,
#        [1. ],
#        [0.1],
#        [0. ]])), ('labels', array([[ 1],
#        [ 1],
#        [ 1],
#        ...,
#        [55],
#        [55],
#        [55]], dtype=uint8)), ('massLoadings', array([[90.48134734],
#        [90.48134734],
#        [90.48134734],
#        ...,
#        [93.56603952],
#        [93.56603952],
#        [93.56603952]])), ('spectra', array([[0.01684698, 0.01575019, 0.01553012, ..., 0.01631328, 0.01523777,
#         0.01464116],
#        [0.01862416, 0.01217942, 0.02092375, ..., 0.01522821, 0.02158774,
#         0.01224737],
#        [0.01634829, 0.01627708, 0.01620733, ..., 0.01681628, 0.01679286,
#         0.0167685 ],
#        ...,
#        [0.01777366, 0.02470746, 0.04042846, ..., 0.52899222, 0.53342443,
# ...

# %%
mass=mat['massLoadings']
a=np.unique(mass)

# %%
y=mat['labels']

# %%
df=mat['spectra']
df=pd.DataFrame(df)
print(df.shape)
# Out:
# (49500, 1701)

# %%
ys=mat['substrateIDs']

# %%
subs=mat['substrateSpectra']
subs=pd.DataFrame(subs)
subs
# Out:
#        0         1         2         3         4         5         6     \
# 0  0.008192  0.008116  0.008042  0.007970  0.007899  0.007830  0.007763
# 1  0.035105  0.035617  0.036458  0.037003  0.037084  0.036102  0.035552
# 2  0.585617  0.585672  0.585179  0.584104  0.585759  0.587581  0.588336
# 3  0.026414  0.026214  0.026014  0.025770  0.025449  0.025250  0.025171
# 4  0.011060  0.011381  0.011618  0.011406  0.010922  0.010713  0.010692
# 5  0.064400  0.064528  0.064613  0.064131  0.063398  0.062792  0.062214
# 6  0.035515  0.035251  0.034737  0.034093  0.033518  0.033043  0.032536
# 7  0.031312  0.031438  0.031556  0.031777  0.031780  0.031608  0.031588
# 8  0.000880  0.001132  0.004165  0.006112  0.005633  0.004667  0.003701
#
#        7         8         9     ...      1691      1692      1693      1694  \
# 0  0.007697  0.007633  0.007570  ...  0.010966  0.010943  0.010919  0.010895
# 1  0.035033  0.034687  0.034424  ...  0.040834  0.040778  0.040760  0.040794
# ...

# %% [markdown]
# ### The whole data

# %%
dfset2=df.copy()
dfset2['Analyte']=y
dfset2['substrate']=ys
dfset2.head(105)
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.016847  0.015750  0.015530  0.014852  0.015202  0.015420  0.016572
# 1    0.018624  0.012179  0.020924  0.003329  0.014498  0.019329  0.011184
# 2    0.016348  0.016277  0.016207  0.016139  0.016066  0.015951  0.015780
# 3    0.015725  0.018253  0.018749  0.017823  0.016850  0.015230  0.017195
# 4    0.018868  0.024683  0.016563  0.020112  0.018959  0.017602  0.016099
# ..        ...       ...       ...       ...       ...       ...       ...
# 100  0.011894  0.029022  0.017123  0.008247  0.002930 -0.000288  0.013144
# 101  0.024892  0.011826  0.011954  0.018210  0.004604  0.016785 -0.001717
# 102  0.022097  0.011850  0.007572  0.002714  0.013751  0.005509  0.012327
# 103  0.011707  0.011613  0.011517  0.011409  0.011346  0.011279  0.011208
# 104  0.010759  0.008472  0.013728  0.013133  0.021637  0.009640  0.007940
#
#             7         8         9  ...      1693      1694      1695  \
# ...

# %% [markdown]
# ### Extracting the substrates

# %%
#hard=[30,40,55]
#dfset5=dfset2[-dfset2["Analyte"].isin(hard)]
dfsub1=dfset2[dfset2['substrate']==1]
dfsub2=dfset2[dfset2['substrate']==2]
dfsub3=dfset2[dfset2['substrate']==3]
dfsub4=dfset2[dfset2['substrate']==4]
dfsub5=dfset2[dfset2['substrate']==5]
dfsub6=dfset2[dfset2['substrate']==6]
dfsub7=dfset2[dfset2['substrate']==7]
dfsub8=dfset2[dfset2['substrate']==8]
dfsub9=dfset2[dfset2['substrate']==9]
#dfset1=pd.DataFrame(dfset1)
df['Analyte']=y
df['substrate']=ys
df.iloc[20000:20006,:]
#yt=dfset5["Analyte"]
dfsub1.head()
#dfset5.shape
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.016847  0.015750  0.015530  0.014852  0.015202  0.015420  0.016572
# 1  0.018624  0.012179  0.020924  0.003329  0.014498  0.019329  0.011184
# 2  0.016348  0.016277  0.016207  0.016139  0.016066  0.015951  0.015780
# 3  0.015725  0.018253  0.018749  0.017823  0.016850  0.015230  0.017195
# 4  0.018868  0.024683  0.016563  0.020112  0.018959  0.017602  0.016099
#
#           7         8         9  ...      1693      1694      1695      1696  \
# 0  0.014220  0.014954  0.014995  ...  0.016104  0.017741  0.017533  0.016542
# 1  0.010919  0.007558  0.017733  ...  0.010701  0.018193  0.017089  0.018461
# 2  0.015613  0.015557  0.015594  ...  0.016926  0.016905  0.016884  0.016862
# 3  0.011854  0.013581  0.011075  ...  0.020200  0.018257  0.012629  0.014090
# 4  0.009405  0.020006  0.019105  ...  0.011581  0.019433  0.015924  0.006780
#
#        1697      1698      1699      1700  Analyte  substrate
# ...

# %%
#dfset5.tail()

# %%
import matplotlib.pylab as pl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
dfset1=df.copy()
spectra=range(0,1701,9)
y1=np.ones(189)
y2=np.ones(189)*2
y3=np.ones(189)*3
y4=np.ones(189)*4
y5=np.ones(189)*5
y6=np.ones(189)*6
y7=np.ones(189)*7
y8=np.ones(189)*8
y9=np.ones(189)*9
z1=dfset1.iloc[0,spectra]
z2=dfset1.iloc[1,spectra]
z3=dfset1.iloc[2,spectra]
z4=dfset1.iloc[3,spectra]
z5=dfset1.iloc[4,spectra]
z6=dfset1.iloc[10000,spectra]
z7=dfset1.iloc[10001,spectra]
z8=dfset1.iloc[10002,spectra]
z9=dfset1.iloc[20000,spectra]
z10=dfset1.iloc[20001,spectra]
z11=dfset1.iloc[20002,spectra]
z12=dfset1.iloc[30000,spectra]
z13=dfset1.iloc[30001,spectra]
z14=dfset1.iloc[30002,spectra]
z15=dfset1.iloc[30003,spectra]
z16=dfset1.iloc[30004,spectra]
z17=dfset1.iloc[40000,spectra]
z18=dfset1.iloc[40001,spectra]
z19=dfset1.iloc[40002,spectra]
z20=dfset1.iloc[40003,spectra]
z21=dfset1.iloc[40004,spectra]
z22=dfset1.iloc[25000,spectra]
z23=dfset1.iloc[25001,spectra]
z24=dfset1.iloc[25002,spectra]
z25=dfset1.iloc[25003,spectra]
z26=dfset1.iloc[25004,spectra]
z27=dfset1.iloc[35000,spectra]
z28=dfset1.iloc[35001,spectra]
z29=dfset1.iloc[35002,spectra]
z30=dfset1.iloc[35003,spectra]
z31=dfset1.iloc[35004,spectra]
z32=dfset1.iloc[35005,spectra]
z33=dfset1.iloc[15000,spectra]
z34=dfset1.iloc[15001,spectra]
z35=dfset1.iloc[15002,spectra]
z36=dfset1.iloc[15003,spectra]
z37=dfset1.iloc[15004,spectra]
z38=dfset1.iloc[10003,spectra]
z39=dfset1.iloc[10004,spectra]
z40=dfset1.iloc[20003,spectra]
z41=dfset1.iloc[20004,spectra]
z42=dfset1.iloc[20005,spectra]
z43=dfset1.iloc[10005,spectra]
z44=dfset1.iloc[40005,spectra]
z45=dfset1.iloc[49494,spectra]
z46=dfset1.iloc[49495,spectra]
z47=dfset1.iloc[49496,spectra]
z48=dfset1.iloc[49497,spectra]
z49=dfset1.iloc[49498,spectra]
z50=dfset1.iloc[49499,spectra]
pl.figure(figsize=(16,10))
ax = pl.subplot(projection='3d')
ax.plot(spectra, y1, z1, color='g')
ax.plot(spectra, y1, z2, color='g')
ax.plot(spectra, y1, z3, color='g')
ax.plot(spectra, y1, z4, color='g')
ax.plot(spectra, y1, z5, color='g')
ax.plot(spectra, y3, z6, color='black')
ax.plot(spectra, y3, z7, color='black')
ax.plot(spectra, y3, z8, color='black')
ax.plot(spectra, y5, z9, color='yellow')
ax.plot(spectra, y5, z10, color='yellow')
ax.plot(spectra, y5, z11, color='yellow')
ax.plot(spectra, y7, z12, color='blue')
ax.plot(spectra, y7, z13, color='blue')
ax.plot(spectra, y7, z14, color='blue')
ax.plot(spectra, y7, z15, color='blue')
ax.plot(spectra, y7, z16, color='blue')
ax.plot(spectra, y9, z17, color='orange')
ax.plot(spectra, y9, z18, color='orange')
ax.plot(spectra, y9, z19, color='orange')
ax.plot(spectra, y9, z20, color='orange')
ax.plot(spectra, y9, z21, color='orange')
ax.plot(spectra, y6, z22, color='magenta')
ax.plot(spectra, y6, z23, color='magenta')
ax.plot(spectra, y6, z24, color='magenta')
ax.plot(spectra, y6, z25, color='magenta')
ax.plot(spectra, y6, z26, color='magenta')
ax.plot(spectra, y4, z27, color='cyan')
ax.plot(spectra, y4, z28, color='cyan')
ax.plot(spectra, y4, z29, color='cyan')
ax.plot(spectra, y4, z30, color='cyan')
ax.plot(spectra, y4, z31, color='cyan')
ax.plot(spectra, y4, z32, color='cyan')
ax.plot(spectra, y2, z33, color='brown')
ax.plot(spectra, y2, z34, color='brown')
ax.plot(spectra, y2, z35, color='brown')
ax.plot(spectra, y2, z36, color='brown')
ax.plot(spectra, y2, z37, color='brown')
ax.plot(spectra, y3, z38, color='black')
ax.plot(spectra, y3, z39, color='black')
ax.plot(spectra, y5, z40, color='yellow')
ax.plot(spectra, y5, z41, color='yellow')
ax.plot(spectra, y5, z42, color='yellow')
ax.plot(spectra, y3, z43, color='black')
ax.plot(spectra, y9, z44, color='orange')
ax.plot(spectra, y8, z45, color='red')
ax.plot(spectra, y8, z46, color='red')
ax.plot(spectra, y8, z47, color='red')
ax.plot(spectra, y8, z48, color='red')
ax.plot(spectra, y8, z49, color='red')
ax.plot(spectra, y8, z50, color='red')
ax.set_xlabel('wavenumber')
ax.set_ylabel('Substrate')
ax.set_zlabel('Reflectance')
ax.legend(labels=['s1','s2','s3','s4','s5','s6','s7','s8','s9'],loc=(1.05,.5), markerscale=50, title="Substrates")
leg=ax.get_legend()
leg.legendHandles[0].set_color('green')
leg.legendHandles[1].set_color('brown')
leg.legendHandles[2].set_color('black')
leg.legendHandles[3].set_color('cyan')
leg.legendHandles[4].set_color('yellow')
leg.legendHandles[5].set_color('magenta')
leg.legendHandles[6].set_color('blue')
leg.legendHandles[7].set_color('red')
leg.legendHandles[8].set_color('orange')

# %% [markdown]
# ### PCA using the raw data

# %%
#All the substrates
from sklearn.decomposition import PCA
#Computing up to first 3 PC
pca = PCA(n_components=3)
pca_result = pca.fit_transform(df.iloc[:,0:1071])
#pca_result = pca.fit_transform(hard_subs.iloc[:,0:1701])
df['pca-one'] = pca_result[:,0]
df['pca-two'] = pca_result[:,1] 
df['pca-three'] = pca_result[:,2]

print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
print('Cumulative explained variation by the 3PCs: {}'.format(pca.explained_variance_ratio_.cumsum()))
# Out:
# Explained variation per principal component: [0.88850037 0.08048147 0.02596336]
# Cumulative explained variation by the 3PCs: [0.88850037 0.96898184 0.9949452 ]

# %%
rndperm = np.random.permutation(df.shape[0])
from mpl_toolkits.mplot3d import Axes3D
colormap=np.array(['green','brown','black','cyan','yellow','magenta','blue','red','orange'])
subs1=df.loc[rndperm,:]["substrate"]-1
#color=cormap[subs]
ax = plt.figure(figsize=(16,10))
ax = plt.subplot(projection='3d')
scatter=ax.scatter(
    xs=df.loc[rndperm,:]["pca-one"], 
    ys=df.loc[rndperm,:]["pca-two"], 
    zs=df.loc[rndperm,:]["pca-three"], 
    c=colormap[subs1]
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
plt.show()

# %% [markdown]
# ### Substrate's effect correction

# %%
mdfsub1=dfsub1.iloc[:,0:1701]
mdfsub2=dfsub2.iloc[:,0:1701]
mdfsub3=dfsub3.iloc[:,0:1701]
mdfsub4=dfsub4.iloc[:,0:1701]
mdfsub5=dfsub5.iloc[:,0:1701]
mdfsub6=dfsub6.iloc[:,0:1701]
mdfsub7=dfsub7.iloc[:,0:1701]
mdfsub8=dfsub8.iloc[:,0:1701]
mdfsub9=dfsub9.iloc[:,0:1701]

# %% [markdown]
# ### Extracting the signatures

# %%
s1=subs.loc[0,:]
s2=subs.loc[1,:]
s3=subs.loc[2,:]
s4=subs.loc[3,:]
s5=subs.loc[4,:]
s6=subs.loc[5,:]
s7=subs.loc[6,:]
s8=subs.loc[7,:]
s9=subs.loc[8,:]

# %%
modsub1=mdfsub1.apply(lambda x : x -(np.sum(np.array(x)*np.array(s1))/np.sum(np.array(s1)*np.array(s1)))*s1,axis=1)
modsub2=mdfsub2.apply(lambda x : x -(np.sum(np.array(x)*np.array(s2))/np.sum(np.array(s2)*np.array(s2)))*s2,axis=1)
modsub3=mdfsub3.apply(lambda x : x -(np.sum(np.array(x)*np.array(s3))/np.sum(np.array(s3)*np.array(s3)))*s3,axis=1)
modsub4=mdfsub4.apply(lambda x : x -(np.sum(np.array(x)*np.array(s4))/np.sum(np.array(s4)*np.array(s4)))*s4,axis=1)
modsub5=mdfsub5.apply(lambda x : x -(np.sum(np.array(x)*np.array(s5))/np.sum(np.array(s5)*np.array(s5)))*s5,axis=1)
modsub6=mdfsub6.apply(lambda x : x -(np.sum(np.array(x)*np.array(s6))/np.sum(np.array(s6)*np.array(s6)))*s6,axis=1)
modsub7=mdfsub7.apply(lambda x : x -(np.sum(np.array(x)*np.array(s7))/np.sum(np.array(s7)*np.array(s7)))*s7,axis=1)
modsub8=mdfsub8.apply(lambda x : x -(np.sum(np.array(x)*np.array(s8))/np.sum(np.array(s8)*np.array(s8)))*s8,axis=1)
modsub9=mdfsub9.apply(lambda x : x -(np.sum(np.array(x)*np.array(s9))/np.sum(np.array(s9)*np.array(s9)))*s9,axis=1)

# %%
#subdft=[modsub1t,modsub2t,modsub3t,modsub4t,modsub5t,modsub6t,modsub7t,modsub8t,modsub9t]
#centt_subs=pd.concat(subdft)
#centt_subs.head()

# %%
subdf=[modsub1,modsub2,modsub3,modsub4,modsub5,modsub6,modsub7,modsub8,modsub9]
cent_subs=pd.concat(subdf)
cent_subs.head()
# Out:
#        0         1         2         3         4         5         6     \
# 0  0.001835  0.000878  0.000793  0.000247  0.000728  0.001072  0.002347
# 1  0.003758 -0.002548  0.006330 -0.011134  0.000164  0.005120 -0.002903
# 2  0.001106  0.001177  0.001245  0.001310  0.001369  0.001383  0.001337
# 3  0.000363  0.003034  0.003668  0.002877  0.002038  0.000546  0.002638
# 4  0.003795  0.009750  0.001765  0.005447  0.004424  0.003195  0.001814
#
#        7         8         9     ...      1691      1692      1693      1694  \
# 0  0.000115  0.000966  0.001123  ... -0.003352 -0.004829 -0.003905 -0.002224
# 1 -0.003049 -0.006294  0.003996  ... -0.010454  0.004719 -0.009114 -0.001578
# 2  0.001292  0.001355  0.001509  ... -0.003437 -0.003414 -0.003390 -0.003366
# 3 -0.002580 -0.000733 -0.003121  ... -0.002536 -0.007373 -0.000276 -0.002173
# 4 -0.004758  0.005961  0.005176  ... -0.003264  0.001135 -0.008510 -0.000614
#
#        1695      1696      1697      1698      1699      1700
# ...

# %% [markdown]
# ### PCA after substrate's effect correction

# %%
from sklearn.decomposition import PCA
#Computing up to first 3 PC
pca = PCA(n_components=3)
pca_result = pca.fit_transform(cent_subs.iloc[:,0:1071])
#pca_result = pca.fit_transform(hard_subs.iloc[:,0:1701])
cent_subs['pca-one'] = pca_result[:,0]
cent_subs['pca-two'] = pca_result[:,1] 
cent_subs['pca-three'] = pca_result[:,2]

print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
print('Cumulative explained variation by the 3PCs: {}'.format(pca.explained_variance_ratio_.cumsum()))
# Out:
# Explained variation per principal component: [0.59578205 0.14852932 0.07879707]
# Cumulative explained variation by the 3PCs: [0.59578205 0.74431137 0.82310844]

# %%
cent_subs['substrate']=ys
cent_subs.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.001835  0.000878  0.000793  0.000247  0.000728  0.001072  0.002347
# 1  0.003758 -0.002548  0.006330 -0.011134  0.000164  0.005120 -0.002903
# 2  0.001106  0.001177  0.001245  0.001310  0.001369  0.001383  0.001337
# 3  0.000363  0.003034  0.003668  0.002877  0.002038  0.000546  0.002638
# 4  0.003795  0.009750  0.001765  0.005447  0.004424  0.003195  0.001814
#
#           7         8         9  ...      1695      1696      1697      1698  \
# 0  0.000115  0.000966  0.001123  ... -0.002386 -0.003332 -0.003701 -0.003463
# 1 -0.003049 -0.006294  0.003996  ... -0.002636 -0.001219  0.000561 -0.004356
# 2  0.001292  0.001355  0.001509  ... -0.003341 -0.003316 -0.003289 -0.003263
# 3 -0.002580 -0.000733 -0.003121  ... -0.007754 -0.006247 -0.003583 -0.004043
# 4 -0.004758  0.005961  0.005176  ... -0.004077 -0.013175 -0.004247 -0.002622
#
#        1699      1700   pca-one   pca-two  pca-three  substrate
# ...

# %%
rndperm = np.random.permutation(df.shape[0])
from plotnine import *
chart = ggplot(cent_subs.loc[rndperm[:49500],:], aes(x='pca-one', y='pca-two', color='substrate') ) \
        + geom_point(size=3,alpha=0.6) \
        + ggtitle("First and Second Principal Components after centering, colored by Substrate")
chart
# Out:
# <ggplot: (163683689924)>

# %% [markdown]
# ### PCA after Normalization

# %%
# Using sklearn
from sklearn.preprocessing import normalize
b=cent_subs.iloc[:,0:1701]
b.head()
# Out:
#        0         1         2         3         4         5         6     \
# 0  0.001835  0.000878  0.000793  0.000247  0.000728  0.001072  0.002347
# 1  0.003758 -0.002548  0.006330 -0.011134  0.000164  0.005120 -0.002903
# 2  0.001106  0.001177  0.001245  0.001310  0.001369  0.001383  0.001337
# 3  0.000363  0.003034  0.003668  0.002877  0.002038  0.000546  0.002638
# 4  0.003795  0.009750  0.001765  0.005447  0.004424  0.003195  0.001814
#
#        7         8         9     ...      1691      1692      1693      1694  \
# 0  0.000115  0.000966  0.001123  ... -0.003352 -0.004829 -0.003905 -0.002224
# 1 -0.003049 -0.006294  0.003996  ... -0.010454  0.004719 -0.009114 -0.001578
# 2  0.001292  0.001355  0.001509  ... -0.003437 -0.003414 -0.003390 -0.003366
# 3 -0.002580 -0.000733 -0.003121  ... -0.002536 -0.007373 -0.000276 -0.002173
# 4 -0.004758  0.005961  0.005176  ... -0.003264  0.001135 -0.008510 -0.000614
#
#        1695      1696      1697      1698      1699      1700
# ...

# %%
#bt=centt_subs.iloc[:,0:1701]
#bt.head()

# %%
#normalize(b)
#b1t=bt.apply(lambda x: x/(x**2).sum()**.5, axis=1)
#b1t.shape

# %%
#normalize(b)
b1=b.apply(lambda x: x/(x**2).sum()**.5, axis=1)
b1.head()
# Out:
#        0         1         2         3         4         5         6     \
# 0  0.009607  0.004595  0.004153  0.001293  0.003809  0.005611  0.012284
# 1  0.013683 -0.009277  0.023046 -0.040534  0.000598  0.018640 -0.010568
# 2  0.005920  0.006296  0.006659  0.007008  0.007325  0.007399  0.007152
# 3  0.001720  0.014365  0.017369  0.013624  0.009649  0.002587  0.012490
# 4  0.014017  0.036012  0.006521  0.020120  0.016342  0.011801  0.006702
#
#        7         8         9     ...      1691      1692      1693      1694  \
# 0  0.000603  0.005059  0.005881  ... -0.017547 -0.025276 -0.020442 -0.011642
# 1 -0.011098 -0.022913  0.014546  ... -0.038060  0.017181 -0.033179 -0.005745
# 2  0.006912  0.007250  0.008074  ... -0.018391 -0.018267 -0.018138 -0.018009
# 3 -0.012215 -0.003470 -0.014777  ... -0.012008 -0.034912 -0.001307 -0.010292
# 4 -0.017573  0.022017  0.019119  ... -0.012055  0.004192 -0.031434 -0.002269
#
#        1695      1696      1697      1698      1699      1700
# ...

# %%
#b1t['substrate']=dfset5["substrate"]
#b1t.head()

# %%
from sklearn.decomposition import PCA
#Computing up to first 3 PC
pca = PCA(n_components=100)
#pca_result = pca.fit_transform(dfset1)
pca_result = pca.fit_transform(b1.iloc[:,0:1701])
b1['pca-one'] = pca_result[:,0]
b1['pca-two'] = pca_result[:,1]
b1['pca-three'] = pca_result[:,2]
#dfset1['pca-one'] = pca_result[:,0]
#dfset1['pca-two'] = pca_result[:,1] 
#dfset1['pca-three'] = pca_result[:,2]
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
print('Cumulative explained variation by the 3PCs: {}'.format(pca.explained_variance_ratio_.cumsum()))
# Out:
# Explained variation per principal component: [0.18910859 0.11955914 0.06851947 0.03623639 0.02020034 0.01627484
#  0.0100474  0.00731329 0.00566599 0.00533418 0.00499098 0.00449792
#  0.00402602 0.00330101 0.00277869 0.00252304 0.00228485 0.00202895
#  0.00192519 0.00187927 0.00174674 0.00143555 0.00140529 0.00139528
#  0.00123986 0.00118079 0.00114403 0.00104662 0.00095596 0.00093923
#  0.00089817 0.00085551 0.00084678 0.00079817 0.00079466 0.00072472
#  0.00071425 0.00066862 0.00066195 0.0006375  0.00061382 0.0005965
#  0.00057119 0.00056813 0.00055406 0.00053072 0.0005296  0.00052079
#  0.00049727 0.00049515 0.0004821  0.00046814 0.00046331 0.0004527
#  0.00044624 0.00044071 0.00043104 0.0004297  0.00042924 0.00042562
#  0.00042395 0.00042173 0.00042143 0.00042053 0.00041962 0.00041771
#  0.00041617 0.00041474 0.00041428 0.00041347 0.0004133  0.00041272
#  0.00041209 0.00041021 0.00040965 0.00040785 0.00040765 0.00040656
# ...

# %%
b1['substrate']=ys
b1.tail()
# Out:
#               0         1         2         3         4         5         6  \
# 43995  0.022945  0.030391 -0.021061  0.000595  0.018469  0.013449 -0.022171
# 43996  0.035904  0.010592 -0.023353 -0.059501 -0.015678 -0.000103 -0.000592
# 43997  0.012271  0.008601  0.012912 -0.024950 -0.018514 -0.012157  0.002842
# 43998 -0.013672 -0.007898 -0.010769 -0.018724 -0.002720 -0.020688 -0.019782
# 43999  0.023768  0.044580 -0.006637 -0.023797 -0.036522  0.026488 -0.002815
#
#               7         8         9  ...      1695      1696      1697  \
# 43995  0.054699 -0.013509  0.018002  ...  0.004712 -0.026322  0.024897
# 43996 -0.032401  0.007539  0.016579  ... -0.029304 -0.012021  0.004537
# 43997  0.008810 -0.008781  0.022915  ... -0.001467  0.007648 -0.008405
# 43998  0.015293  0.039859  0.024351  ... -0.051293  0.006571  0.008780
# 43999  0.004729  0.023445 -0.021209  ... -0.039846  0.012378  0.009469
#
#            1698      1699      1700   pca-one   pca-two  pca-three  substrate
# ...

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
colormap=np.array(['green','brown','black','cyan','yellow','magenta','blue','red','orange'])
subs1=b1.loc[rndperm,:]["substrate"]-1
#color=colormap[subs]
ax = plt.figure(figsize=(16,10)).gca(projection='3d')
scatter=ax.scatter(
    xs=b1.loc[rndperm,:]["pca-one"], 
    ys=b1.loc[rndperm,:]["pca-two"], 
    zs=b1.loc[rndperm,:]["pca-three"], 
    c=colormap[subs1]
)
ax.set_xlabel('pca-one')
ax.set_ylabel('pca-two')
ax.set_zlabel('pca-three')
ax.view_init(azim=150)
plt.show()

# %%
a1=np.array(dfsub1['Analyte'].values.tolist())
a2=np.array(dfsub2['Analyte'].values.tolist())
a3=np.array(dfsub3['Analyte'].values.tolist())
a4=np.array(dfsub4['Analyte'].values.tolist())
a5=np.array(dfsub5['Analyte'].values.tolist())
a6=np.array(dfsub6['Analyte'].values.tolist())
a7=np.array(dfsub7['Analyte'].values.tolist())
a8=np.array(dfsub8['Analyte'].values.tolist())
a9=np.array(dfsub9['Analyte'].values.tolist())
y=np.concatenate((a1,a2,a3,a4,a5,a6,a7,a8,a9),axis=None)
#print(len(y))

# %%
Xc_train, Xc_test, yc_train, yc_test = train_test_split(pca_result,y,test_size=0.2,random_state=0)
Xc_train=pd.DataFrame(Xc_train)
Xc_test=pd.DataFrame(Xc_test)
Xc_train.to_csv("c:/Users/eacun/NRL/NRLDataset/train/Subs/X_train.csv",index=False,header=False)
Xc_test.to_csv("c:/Users/eacun/NRL/NRLDataset/test/Subs/X_test.csv",index=False,header=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-aaa5a83afbf0> in <module>
# ----> 1 Xc_train, Xc_test, yc_train, yc_test = train_test_split(pca_result,y,test_size=0.2,random_state=0)
#       2 Xc_train=pd.DataFrame(Xc_train)
#       3 Xc_test=pd.DataFrame(Xc_test)
#       4 Xc_train.to_csv("c:/Users/eacun/NRL/NRLDataset/train/Subs/X_train.csv",index=False,header=False)
#       5 Xc_test.to_csv("c:/Users/eacun/NRL/NRLDataset/test/Subs/X_test.csv",index=False,header=False)
#
# NameError: name 'train_test_split' is not defined

# %%
np.savetxt('c:/Users/eacun/NRL/NRLDataset/train/y_train.csv', yc_train) 
np.savetxt('c:/Users/eacun/NRL/NRLDataset/test/y_test.csv', yc_test)
