# %%
import scipy.io
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mat = scipy.io.loadmat('C:/Users/eacun/Downloads/dataset55_release2.mat')
mat.items()
# Out:
# dict_items([('__header__', b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jul 22 14:13:11 2020'), ('__version__', '1.0'), ('__globals__', []), ('addedNoisePercent', array([[0.1],
#        [0.5],
#        [0. ],
#        ...,
#        [1. ],
#        [0.1],
#        [0. ]])), ('labels', array([[ 1],
#        [ 1],
#        [ 1],
#        ...,
#        [55],
#        [55],
#        [55]], dtype=uint8)), ('massLoadings', array([[90.48134734],
#        [90.48134734],
#        [90.48134734],
#        ...,
#        [93.56603952],
#        [93.56603952],
#        [93.56603952]])), ('spectra', array([[0.01684698, 0.01575019, 0.01553012, ..., 0.01631328, 0.01523777,
#         0.01464116],
#        [0.01862416, 0.01217942, 0.02092375, ..., 0.01522821, 0.02158774,
#         0.01224737],
#        [0.01634829, 0.01627708, 0.01620733, ..., 0.01681628, 0.01679286,
#         0.0167685 ],
#        ...,
#        [0.01777366, 0.02470746, 0.04042846, ..., 0.52899222, 0.53342443,
#         0.54125978],
#        [0.03112273, 0.02996503, 0.03299245, ..., 0.54179967, 0.53942979,
#         0.54275879],
#        [0.03236588, 0.0324536 , 0.03238276, ..., 0.54378712, 0.54383177,
#         0.54386556]])), ('substrateIDs', array([[1],
#        [1],
#        [1],
#        ...,
#        [8],
#        [8],
#        [8]], dtype=uint8)), ('substrateSpectra', array([[0.008192, 0.008116, 0.008042, ..., 0.010792, 0.010765, 0.010737],
#        [0.035105, 0.035617, 0.036458, ..., 0.041036, 0.041051, 0.04107 ],
#        [0.585617, 0.585672, 0.585179, ..., 0.559301, 0.559264, 0.55923 ],
#        ...,
#        [0.035515, 0.035251, 0.034737, ..., 0.247776, 0.246856, 0.245963],
#        [0.031312, 0.031438, 0.031556, ..., 0.569884, 0.56993 , 0.569966],
#        [0.00088 , 0.001132, 0.004165, ..., 0.008746, 0.008464, 0.008364]]))])

# %%
y=mat['labels']
df=mat['spectra']
df=pd.DataFrame(df)
print(df.shape)
# Out:
# (49500, 1701)

# %%
ys=mat['substrateIDs']
subs=mat['substrateSpectra']
subs=pd.DataFrame(subs)

# %%
df['Analyte']=y
df['substrate']=ys

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.016847  0.015750  0.015530  0.014852  0.015202  0.015420  0.016572
# 1  0.018624  0.012179  0.020924  0.003329  0.014498  0.019329  0.011184
# 2  0.016348  0.016277  0.016207  0.016139  0.016066  0.015951  0.015780
# 3  0.015725  0.018253  0.018749  0.017823  0.016850  0.015230  0.017195
# 4  0.018868  0.024683  0.016563  0.020112  0.018959  0.017602  0.016099
#
#           7         8         9  ...      1693      1694      1695      1696  \
# 0  0.014220  0.014954  0.014995  ...  0.016104  0.017741  0.017533  0.016542
# 1  0.010919  0.007558  0.017733  ...  0.010701  0.018193  0.017089  0.018461
# 2  0.015613  0.015557  0.015594  ...  0.016926  0.016905  0.016884  0.016862
# 3  0.011854  0.013581  0.011075  ...  0.020200  0.018257  0.012629  0.014090
# 4  0.009405  0.020006  0.019105  ...  0.011581  0.019433  0.015924  0.006780
#
#        1697      1698      1699      1700  Analyte  substrate
# 0  0.016122  0.016313  0.015238  0.014641        1          1
# 1  0.020192  0.015228  0.021588  0.012247        1          1
# 2  0.016839  0.016816  0.016793  0.016769        1          1
# 3  0.016704  0.016195  0.017715  0.011852        1          1
# 4  0.015658  0.017236  0.019725  0.015868        1          1
#
# [5 rows x 1703 columns]

# %%
df = shuffle(df)
df
# Out:
#               0         1         2         3         4         5         6  \
# 35227  0.053886  0.052843  0.053525  0.050323  0.052736  0.052434  0.052380
# 1060   0.013661  0.013619  0.013589  0.013569  0.013548  0.013490  0.013413
# 37445  0.039075  0.046343  0.055086  0.057667  0.062160  0.062351  0.065333
# 40927 -0.003422  0.010735 -0.004629  0.002653  0.031606  0.016140  0.017083
# 9690   0.609668  0.610580  0.605106  0.611551  0.607298  0.590359  0.605807
# ...         ...       ...       ...       ...       ...       ...       ...
# 32694  0.036623  0.036141  0.036130  0.036554  0.034435  0.032379  0.032641
# 34083  0.095041  0.095261  0.095760  0.096328  0.096819  0.096773  0.096514
# 4351   0.009046  0.008946  0.008861  0.008808  0.008760  0.008700  0.008636
# 22800  0.064103  0.064175  0.064220  0.063711  0.062966  0.062341  0.061745
# 24624  0.063524  0.063727  0.064935  0.063921  0.060555  0.061584  0.060830
#
#               7         8         9  ...      1693      1694      1695  \
# 35227  0.057063  0.053620  0.054398  ...  0.559843  0.562179  0.561685
# 1060   0.013335  0.013267  0.013211  ...  0.015072  0.015034  0.015012
# 37445  0.066681  0.066459  0.066239  ...  0.569777  0.570059  0.571108
# 40927  0.027732  0.021490  0.019217  ...  0.024102  0.008696 -0.001042
# 9690   0.606439  0.567658  0.603224  ...  0.600901  0.612432  0.633285
# ...         ...       ...       ...  ...       ...       ...       ...
# 32694  0.032704  0.031499  0.032783  ...  0.251498  0.249948  0.246860
# 34083  0.096227  0.096180  0.096426  ...  0.579447  0.579684  0.580066
# 4351   0.008573  0.008505  0.008418  ...  0.011671  0.011647  0.011623
# 22800  0.061086  0.060196  0.059012  ...  0.267580  0.266922  0.266251
# 24624  0.061861  0.060368  0.059000  ...  0.270901  0.272367  0.270350
#
#            1696      1697      1698      1699      1700  Analyte  substrate
# 35227  0.565123  0.562639  0.564010  0.567216  0.558117       23          4
# 1060   0.015004  0.014989  0.014964  0.014930  0.014901       11          1
# 37445  0.571441  0.569208  0.571265  0.572476  0.571969       45          4
# 40927  0.008737  0.009432  0.016345  0.023727  0.014672       25          9
# 9690   0.615016  0.606017  0.611756  0.606554  0.627114       42          3
# ...         ...       ...       ...       ...       ...      ...        ...
# 32694  0.247835  0.246707  0.244758  0.244377  0.244184       52          7
# 34083  0.580508  0.580878  0.581115  0.581191  0.581256       11          4
# 4351   0.011598  0.011571  0.011545  0.011519  0.011491       44          1
# 22800  0.265589  0.264931  0.264289  0.263702  0.263060        9          6
# 24624  0.271251  0.271007  0.271739  0.269792  0.267751       27          6
#
# [49500 rows x 1703 columns]

# %%
df.reset_index(inplace=True, drop=True) 
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.053886  0.052843  0.053525  0.050323  0.052736  0.052434  0.052380
# 1  0.013661  0.013619  0.013589  0.013569  0.013548  0.013490  0.013413
# 2  0.039075  0.046343  0.055086  0.057667  0.062160  0.062351  0.065333
# 3 -0.003422  0.010735 -0.004629  0.002653  0.031606  0.016140  0.017083
# 4  0.609668  0.610580  0.605106  0.611551  0.607298  0.590359  0.605807
#
#           7         8         9  ...      1693      1694      1695      1696  \
# 0  0.057063  0.053620  0.054398  ...  0.559843  0.562179  0.561685  0.565123
# 1  0.013335  0.013267  0.013211  ...  0.015072  0.015034  0.015012  0.015004
# 2  0.066681  0.066459  0.066239  ...  0.569777  0.570059  0.571108  0.571441
# 3  0.027732  0.021490  0.019217  ...  0.024102  0.008696 -0.001042  0.008737
# 4  0.606439  0.567658  0.603224  ...  0.600901  0.612432  0.633285  0.615016
#
#        1697      1698      1699      1700  Analyte  substrate
# 0  0.562639  0.564010  0.567216  0.558117       23          4
# 1  0.014989  0.014964  0.014930  0.014901       11          1
# 2  0.569208  0.571265  0.572476  0.571969       45          4
# 3  0.009432  0.016345  0.023727  0.014672       25          9
# 4  0.606017  0.611756  0.606554  0.627114       42          3
#
# [5 rows x 1703 columns]

# %%
dfsub1=df[df['substrate']==1]
dfsub2=df[df['substrate']==2]
dfsub3=df[df['substrate']==3]
dfsub4=df[df['substrate']==4]
dfsub5=df[df['substrate']==5]
dfsub6=df[df['substrate']==6]
dfsub7=df[df['substrate']==7]
dfsub8=df[df['substrate']==8]
dfsub9=df[df['substrate']==9]

# %%
mdfsub1=dfsub1.iloc[:,0:1701]
mdfsub2=dfsub2.iloc[:,0:1701]
mdfsub3=dfsub3.iloc[:,0:1701]
mdfsub4=dfsub4.iloc[:,0:1701]
mdfsub5=dfsub5.iloc[:,0:1701]
mdfsub6=dfsub6.iloc[:,0:1701]
mdfsub7=dfsub7.iloc[:,0:1701]
mdfsub8=dfsub8.iloc[:,0:1701]
mdfsub9=dfsub9.iloc[:,0:1701]

# %%
dfsub1.head()
# Out:
#            0         1         2         3         4         5         6  \
# 1   0.013661  0.013619  0.013589  0.013569  0.013548  0.013490  0.013413
# 6   0.010956  0.010716  0.010511  0.010310  0.010244  0.010286  0.010404
# 8   0.013811  0.013746  0.013683  0.013622  0.013560  0.013501  0.013443
# 10  0.012113  0.015129  0.010826  0.012140  0.009835  0.015475  0.011331
# 18  0.026074  0.022526  0.009797  0.015527  0.008499  0.020815  0.017164
#
#            7         8         9  ...      1693      1694      1695      1696  \
# 1   0.013335  0.013267  0.013211  ...  0.015072  0.015034  0.015012  0.015004
# 6   0.010591  0.010708  0.010725  ...  0.012959  0.012926  0.012889  0.012853
# 8   0.013385  0.013329  0.013274  ...  0.015310  0.015287  0.015263  0.015239
# 10  0.013913  0.013318  0.014631  ...  0.012151  0.015526  0.009729  0.017058
# 18  0.019058  0.005669  0.003427  ...  0.035775  0.033229  0.003737  0.032956
#
#         1697      1698      1699      1700  Analyte  substrate
# 1   0.014989  0.014964  0.014930  0.014901       11          1
# 6   0.012827  0.012817  0.012817  0.012784        4          1
# 8   0.015213  0.015187  0.015161  0.015133       47          1
# 10  0.011520  0.011540  0.014016  0.014679       35          1
# 18  0.027971  0.011252  0.027441  0.014849       26          1
#
# [5 rows x 1703 columns]

# %%
s1=subs.loc[0,:]
s2=subs.loc[1,:]
s3=subs.loc[2,:]
s4=subs.loc[3,:]
s5=subs.loc[4,:]
s6=subs.loc[5,:]
s7=subs.loc[6,:]
s8=subs.loc[7,:]
s9=subs.loc[8,:]

# %%
modsub1=mdfsub1.apply(lambda x : x -(np.sum(np.array(x)*np.array(s1))/np.sum(np.array(s1)*np.array(s1)))*s1,axis=1)
modsub2=mdfsub2.apply(lambda x : x -(np.sum(np.array(x)*np.array(s2))/np.sum(np.array(s2)*np.array(s2)))*s2,axis=1)
modsub3=mdfsub3.apply(lambda x : x -(np.sum(np.array(x)*np.array(s3))/np.sum(np.array(s3)*np.array(s3)))*s3,axis=1)
modsub4=mdfsub4.apply(lambda x : x -(np.sum(np.array(x)*np.array(s4))/np.sum(np.array(s4)*np.array(s4)))*s4,axis=1)
modsub5=mdfsub5.apply(lambda x : x -(np.sum(np.array(x)*np.array(s5))/np.sum(np.array(s5)*np.array(s5)))*s5,axis=1)
modsub6=mdfsub6.apply(lambda x : x -(np.sum(np.array(x)*np.array(s6))/np.sum(np.array(s6)*np.array(s6)))*s6,axis=1)
modsub7=mdfsub7.apply(lambda x : x -(np.sum(np.array(x)*np.array(s7))/np.sum(np.array(s7)*np.array(s7)))*s7,axis=1)
modsub8=mdfsub8.apply(lambda x : x -(np.sum(np.array(x)*np.array(s8))/np.sum(np.array(s8)*np.array(s8)))*s8,axis=1)
modsub9=mdfsub9.apply(lambda x : x -(np.sum(np.array(x)*np.array(s9))/np.sum(np.array(s9)*np.array(s9)))*s9,axis=1)

# %%
subdf=[modsub1,modsub2,modsub3,modsub4,modsub5,modsub6,modsub7,modsub8,modsub9]
cent_subs=pd.concat(subdf)
cent_subs.head()
# Out:
#         0         1         2         3         4         5         6     \
# 1   0.001380  0.001452  0.001533  0.001622  0.001707  0.001752  0.001776
# 6   0.000702  0.000557  0.000445  0.000334  0.000356  0.000485  0.000687
# 8   0.001119  0.001172  0.001224  0.001273  0.001322  0.001370  0.001415
# 10  0.000489  0.003613 -0.000585  0.000830 -0.001373  0.004364  0.000316
# 18  0.009607  0.006210 -0.006369 -0.000495 -0.007380  0.005075  0.001559
#
#         7         8         9     ...      1691      1692      1693      1694  \
# 1   0.001796  0.001824  0.001863  ... -0.001316 -0.001302 -0.001297 -0.001299
# 6   0.000956  0.001153  0.001249  ... -0.000679 -0.000700 -0.000708 -0.000712
# 8   0.001460  0.001503  0.001545  ... -0.001636 -0.001622 -0.001607 -0.001593
# 10  0.002991  0.002487  0.003889  ... -0.004882 -0.002928 -0.003343  0.000066
# 18  0.003586 -0.009675 -0.011790  ... -0.006886  0.005758  0.013825  0.011328
#
#         1695      1696      1697      1698      1699      1700
# 1  -0.001283 -0.001253 -0.001228 -0.001214 -0.001207 -0.001195
# 6  -0.000718 -0.000722 -0.000715 -0.000692 -0.000658 -0.000656
# 8  -0.001578 -0.001564 -0.001548 -0.001533 -0.001518 -0.001502
# 10 -0.005695  0.001669 -0.003831 -0.003774 -0.001259 -0.000556
# 18 -0.018114  0.011155  0.006225 -0.010443  0.005800 -0.006735
#
# [5 rows x 1701 columns]

# %%
cent_subs.shape
# Out:
# (49500, 1701)

# %%
# Using sklearn
from sklearn.preprocessing import normalize
b=cent_subs.iloc[:,0:1701]
b.head()
# Out:
#         0         1         2         3         4         5         6     \
# 1   0.001380  0.001452  0.001533  0.001622  0.001707  0.001752  0.001776
# 6   0.000702  0.000557  0.000445  0.000334  0.000356  0.000485  0.000687
# 8   0.001119  0.001172  0.001224  0.001273  0.001322  0.001370  0.001415
# 10  0.000489  0.003613 -0.000585  0.000830 -0.001373  0.004364  0.000316
# 18  0.009607  0.006210 -0.006369 -0.000495 -0.007380  0.005075  0.001559
#
#         7         8         9     ...      1691      1692      1693      1694  \
# 1   0.001796  0.001824  0.001863  ... -0.001316 -0.001302 -0.001297 -0.001299
# 6   0.000956  0.001153  0.001249  ... -0.000679 -0.000700 -0.000708 -0.000712
# 8   0.001460  0.001503  0.001545  ... -0.001636 -0.001622 -0.001607 -0.001593
# 10  0.002991  0.002487  0.003889  ... -0.004882 -0.002928 -0.003343  0.000066
# 18  0.003586 -0.009675 -0.011790  ... -0.006886  0.005758  0.013825  0.011328
#
#         1695      1696      1697      1698      1699      1700
# 1  -0.001283 -0.001253 -0.001228 -0.001214 -0.001207 -0.001195
# 6  -0.000718 -0.000722 -0.000715 -0.000692 -0.000658 -0.000656
# 8  -0.001578 -0.001564 -0.001548 -0.001533 -0.001518 -0.001502
# 10 -0.005695  0.001669 -0.003831 -0.003774 -0.001259 -0.000556
# 18 -0.018114  0.011155  0.006225 -0.010443  0.005800 -0.006735
#
# [5 rows x 1701 columns]

# %%
#normalize(b)
b1=b.apply(lambda x: x/(x**2).sum()**.5, axis=1)
b1.head()
# Out:
#         0         1         2         3         4         5         6     \
# 1   0.013141  0.013822  0.014595  0.015439  0.016248  0.016681  0.016904
# 6   0.009744  0.007730  0.006177  0.004631  0.004943  0.006737  0.009541
# 8   0.012618  0.013216  0.013802  0.014364  0.014912  0.015452  0.015965
# 10  0.003365  0.024867 -0.004026  0.005715 -0.009451  0.030039  0.002174
# 18  0.020919  0.013524 -0.013869 -0.001078 -0.016069  0.011051  0.003395
#
#         7         8         9     ...      1691      1692      1693      1694  \
# 1   0.017100  0.017368  0.017736  ... -0.012528 -0.012396 -0.012347 -0.012366
# 6   0.013278  0.016009  0.017344  ... -0.009425 -0.009722 -0.009833 -0.009882
# 8   0.016464  0.016951  0.017432  ... -0.018451 -0.018293 -0.018130 -0.017969
# 10  0.020587  0.017114  0.026768  ... -0.033600 -0.020150 -0.023007  0.000457
# 18  0.007808 -0.021068 -0.025673  ... -0.014994  0.012538  0.030105  0.024666
#
#         1695      1696      1697      1698      1699      1700
# 1  -0.012213 -0.011931 -0.011689 -0.011558 -0.011493 -0.011377
# 6  -0.009966 -0.010024 -0.009920 -0.009607 -0.009138 -0.009109
# 8  -0.017803 -0.017638 -0.017462 -0.017294 -0.017121 -0.016942
# 10 -0.039198  0.011489 -0.026365 -0.025974 -0.008668 -0.003827
# 18 -0.039444  0.024290  0.013554 -0.022740  0.012631 -0.014665
#
# [5 rows x 1701 columns]

# %%
a1=np.array(dfsub1['Analyte'].values.tolist())
a2=np.array(dfsub2['Analyte'].values.tolist())
a3=np.array(dfsub3['Analyte'].values.tolist())
a4=np.array(dfsub4['Analyte'].values.tolist())
a5=np.array(dfsub5['Analyte'].values.tolist())
a6=np.array(dfsub6['Analyte'].values.tolist())
a7=np.array(dfsub7['Analyte'].values.tolist())
a8=np.array(dfsub8['Analyte'].values.tolist())
a9=np.array(dfsub9['Analyte'].values.tolist())
y=np.concatenate((a1,a2,a3,a4,a5,a6,a7,a8,a9),axis=None)
print(y)
# Out:
# [11  4 47 ...  9 34  9]

# %%
import tensorflow as tf
from tensorflow import keras
import os
import tempfile
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score, precision_score, roc_auc_score
import keras
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.utils import to_categorical
import time

# %%
# Configuration options
feature_vector_length = 1701
num_classes = 55
X=b1.iloc[:,0:1701]

X_train, X_test, Y_train, Y_test = train_test_split(X,y, test_size=0.2,random_state=0)
# Convert target classes to categorical ones
ytrain=Y_train-1
ytest=Y_test-1
Y_train = to_categorical(ytrain, num_classes)
Y_test = to_categorical(ytest, num_classes)
print('Train dimension:')
print(X_train.shape)
print('Test dimension:')
print(Y_test.shape)
# Out:
# Train dimension:
# (39600, 1701)
# Test dimension:
# (9900, 55)

# %%
# Set the input shape
input_shape = (feature_vector_length,)
print(f'Feature shape: {input_shape}')

# Create the model
model = Sequential()
model.add(Dropout(0.3, input_shape=input_shape))
model.add(Dense(300, input_shape=input_shape, activation='relu'))
model.add(Dense(200, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# Feature shape: (1701,)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout (Dropout)            (None, 1701)              0
# _________________________________________________________________
# dense (Dense)                (None, 300)               510600
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               60200
# _________________________________________________________________
# dense_2 (Dense)              (None, 55)                11055
# =================================================================
# Total params: 581,855
# Trainable params: 581,855
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Configure the model and start training
import time
start_time = time.time()
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
baseline_history=model.fit(X_train, Y_train, epochs=100, batch_size=150, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/100
# 212/212 [==============================] - 2s 9ms/step - loss: 2.4206 - accuracy: 0.4541 - val_loss: 1.1241 - val_accuracy: 0.7475
# Epoch 2/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.9958 - accuracy: 0.7612 - val_loss: 0.8770 - val_accuracy: 0.7986
# Epoch 3/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.8040 - accuracy: 0.8009 - val_loss: 0.8152 - val_accuracy: 0.8051
# Epoch 4/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.6958 - accuracy: 0.8233 - val_loss: 0.7970 - val_accuracy: 0.8078
# Epoch 5/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.6201 - accuracy: 0.8390 - val_loss: 0.7784 - val_accuracy: 0.8080
# Epoch 6/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.5415 - accuracy: 0.8566 - val_loss: 0.7798 - val_accuracy: 0.8093
# Epoch 7/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.4864 - accuracy: 0.8689 - val_loss: 0.7796 - val_accuracy: 0.8083
# Epoch 8/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.4319 - accuracy: 0.8832 - val_loss: 0.7860 - val_accuracy: 0.8080
# Epoch 9/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.3830 - accuracy: 0.8948 - val_loss: 0.8018 - val_accuracy: 0.8088
# Epoch 10/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.3448 - accuracy: 0.9047 - val_loss: 0.8081 - val_accuracy: 0.8057
# Epoch 11/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.2988 - accuracy: 0.9165 - val_loss: 0.8193 - val_accuracy: 0.8087
# Epoch 12/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.2673 - accuracy: 0.9255 - val_loss: 0.8396 - val_accuracy: 0.8068
# Epoch 13/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.2360 - accuracy: 0.9337 - val_loss: 0.8489 - val_accuracy: 0.8035
# Epoch 14/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.2108 - accuracy: 0.9420 - val_loss: 0.8793 - val_accuracy: 0.8019
# Epoch 15/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.1814 - accuracy: 0.9485 - val_loss: 0.8802 - val_accuracy: 0.8054
# Epoch 16/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.1627 - accuracy: 0.9547 - val_loss: 0.8941 - val_accuracy: 0.8010
# Epoch 17/100
# 212/212 [==============================] - 2s 7ms/step - loss: 0.1459 - accuracy: 0.9587 - val_loss: 0.9099 - val_accuracy: 0.8029
# Epoch 18/100
# 212/212 [==============================] - 2s 7ms/step - loss: 0.1377 - accuracy: 0.9606 - val_loss: 0.9103 - val_accuracy: 0.8015
# Epoch 19/100
# 212/212 [==============================] - 2s 7ms/step - loss: 0.1192 - accuracy: 0.9672 - val_loss: 0.9272 - val_accuracy: 0.8054
# Epoch 20/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.1121 - accuracy: 0.9685 - val_loss: 0.9423 - val_accuracy: 0.8028
# Epoch 21/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.1037 - accuracy: 0.9712 - val_loss: 0.9449 - val_accuracy: 0.8047
# Epoch 22/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0972 - accuracy: 0.9724 - val_loss: 0.9641 - val_accuracy: 0.7992
# Epoch 23/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0913 - accuracy: 0.9742 - val_loss: 0.9625 - val_accuracy: 0.8044
# Epoch 24/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0830 - accuracy: 0.9769 - val_loss: 0.9682 - val_accuracy: 0.8014
# Epoch 25/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0772 - accuracy: 0.9785 - val_loss: 0.9716 - val_accuracy: 0.8034
# Epoch 26/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0733 - accuracy: 0.9789 - val_loss: 0.9762 - val_accuracy: 0.8020
# Epoch 27/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0655 - accuracy: 0.9823 - val_loss: 0.9845 - val_accuracy: 0.7999
# Epoch 28/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0666 - accuracy: 0.9802 - val_loss: 1.0009 - val_accuracy: 0.7991
# Epoch 29/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0619 - accuracy: 0.9822 - val_loss: 1.0039 - val_accuracy: 0.8004
# Epoch 30/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0639 - accuracy: 0.9817 - val_loss: 1.0081 - val_accuracy: 0.7976
# Epoch 31/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0554 - accuracy: 0.9845 - val_loss: 1.0258 - val_accuracy: 0.7982
# Epoch 32/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0546 - accuracy: 0.9842 - val_loss: 1.0294 - val_accuracy: 0.7975
# Epoch 33/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0515 - accuracy: 0.9847 - val_loss: 1.0367 - val_accuracy: 0.7970
# Epoch 34/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0472 - accuracy: 0.9864 - val_loss: 1.0397 - val_accuracy: 0.7973
# Epoch 35/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0495 - accuracy: 0.9854 - val_loss: 1.0377 - val_accuracy: 0.8015
# Epoch 36/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0502 - accuracy: 0.9852 - val_loss: 1.0601 - val_accuracy: 0.7961
# Epoch 37/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0450 - accuracy: 0.9871 - val_loss: 1.0589 - val_accuracy: 0.7965
# Epoch 38/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0430 - accuracy: 0.9870 - val_loss: 1.0577 - val_accuracy: 0.7972
# Epoch 39/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0413 - accuracy: 0.9881 - val_loss: 1.0684 - val_accuracy: 0.7984
# Epoch 40/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0430 - accuracy: 0.9867 - val_loss: 1.0725 - val_accuracy: 0.7975
# Epoch 41/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0392 - accuracy: 0.9886 - val_loss: 1.0812 - val_accuracy: 0.7985
# Epoch 42/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0393 - accuracy: 0.9883 - val_loss: 1.0889 - val_accuracy: 0.7999
# Epoch 43/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0382 - accuracy: 0.9883 - val_loss: 1.0903 - val_accuracy: 0.7985
# Epoch 44/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0372 - accuracy: 0.9884 - val_loss: 1.0864 - val_accuracy: 0.7963
# Epoch 45/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0354 - accuracy: 0.9893 - val_loss: 1.0952 - val_accuracy: 0.8003
# Epoch 46/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0371 - accuracy: 0.9891 - val_loss: 1.1027 - val_accuracy: 0.8006
# Epoch 47/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0338 - accuracy: 0.9900 - val_loss: 1.1092 - val_accuracy: 0.7982
# Epoch 48/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0313 - accuracy: 0.9914 - val_loss: 1.1172 - val_accuracy: 0.7994
# Epoch 49/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0332 - accuracy: 0.9900 - val_loss: 1.0986 - val_accuracy: 0.8013
# Epoch 50/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0333 - accuracy: 0.9895 - val_loss: 1.1161 - val_accuracy: 0.7991
# Epoch 51/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0329 - accuracy: 0.9894 - val_loss: 1.0979 - val_accuracy: 0.7990
# Epoch 52/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0318 - accuracy: 0.9899 - val_loss: 1.1195 - val_accuracy: 0.8000
# Epoch 53/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0320 - accuracy: 0.9900 - val_loss: 1.1177 - val_accuracy: 0.7973
# Epoch 54/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0285 - accuracy: 0.9918 - val_loss: 1.1391 - val_accuracy: 0.7970
# Epoch 55/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0306 - accuracy: 0.9908 - val_loss: 1.1509 - val_accuracy: 0.7953
# Epoch 56/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0290 - accuracy: 0.9907 - val_loss: 1.1426 - val_accuracy: 0.7975
# Epoch 57/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0294 - accuracy: 0.9905 - val_loss: 1.1488 - val_accuracy: 0.7958
# Epoch 58/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0283 - accuracy: 0.9914 - val_loss: 1.1618 - val_accuracy: 0.7982
# Epoch 59/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0299 - accuracy: 0.9907 - val_loss: 1.1590 - val_accuracy: 0.7989
# Epoch 60/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0267 - accuracy: 0.9915 - val_loss: 1.1575 - val_accuracy: 0.7960
# Epoch 61/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0299 - accuracy: 0.9904 - val_loss: 1.1641 - val_accuracy: 0.7957
# Epoch 62/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0248 - accuracy: 0.9929 - val_loss: 1.1745 - val_accuracy: 0.7951
# Epoch 63/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0283 - accuracy: 0.9915 - val_loss: 1.1839 - val_accuracy: 0.7976
# Epoch 64/100
# 212/212 [==============================] - 2s 8ms/step - loss: 0.0267 - accuracy: 0.9920 - val_loss: 1.1741 - val_accuracy: 0.7960
# Epoch 65/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0245 - accuracy: 0.9924 - val_loss: 1.1811 - val_accuracy: 0.7963
# Epoch 66/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0212 - accuracy: 0.9938 - val_loss: 1.1878 - val_accuracy: 0.7953
# Epoch 67/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0250 - accuracy: 0.9915 - val_loss: 1.2072 - val_accuracy: 0.7932
# Epoch 68/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0248 - accuracy: 0.9924 - val_loss: 1.1970 - val_accuracy: 0.7970
# Epoch 69/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0248 - accuracy: 0.9921 - val_loss: 1.2101 - val_accuracy: 0.7972
# Epoch 70/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0217 - accuracy: 0.9930 - val_loss: 1.2145 - val_accuracy: 0.7946
# Epoch 71/100
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0222 - accuracy: 0.9925 - val_loss: 1.2121 - val_accuracy: 0.7963
# Epoch 72/100
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0270 - accuracy: 0.9913 - val_loss: 1.2208 - val_accuracy: 0.7928
# Epoch 73/100
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0230 - accuracy: 0.9933 - val_loss: 1.2023 - val_accuracy: 0.7961
# Epoch 74/100
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0234 - accuracy: 0.9927 - val_loss: 1.2206 - val_accuracy: 0.7947
# Epoch 75/100
# 212/212 [==============================] - 2s 11ms/step - loss: 0.0252 - accuracy: 0.9918 - val_loss: 1.2328 - val_accuracy: 0.7926
# Epoch 76/100
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0232 - accuracy: 0.9929 - val_loss: 1.2315 - val_accuracy: 0.7934
# Epoch 77/100
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0196 - accuracy: 0.9942 - val_loss: 1.2243 - val_accuracy: 0.7939
# Epoch 78/100
# 212/212 [==============================] - 2s 10ms/step - loss: 0.0212 - accuracy: 0.9928 - val_loss: 1.2396 - val_accuracy: 0.7931
# Epoch 79/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0240 - accuracy: 0.9917 - val_loss: 1.2449 - val_accuracy: 0.7938
# Epoch 80/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0236 - accuracy: 0.9926 - val_loss: 1.2445 - val_accuracy: 0.7905
# Epoch 81/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0217 - accuracy: 0.9928 - val_loss: 1.2645 - val_accuracy: 0.7910
# Epoch 82/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0209 - accuracy: 0.9934 - val_loss: 1.2639 - val_accuracy: 0.7919
# Epoch 83/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0197 - accuracy: 0.9935 - val_loss: 1.2673 - val_accuracy: 0.7931
# Epoch 84/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0203 - accuracy: 0.9933 - val_loss: 1.2735 - val_accuracy: 0.7943
# Epoch 85/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0222 - accuracy: 0.9932 - val_loss: 1.2630 - val_accuracy: 0.7934
# Epoch 86/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0224 - accuracy: 0.9927 - val_loss: 1.2740 - val_accuracy: 0.7934
# Epoch 87/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0202 - accuracy: 0.9936 - val_loss: 1.2767 - val_accuracy: 0.7941
# Epoch 88/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0226 - accuracy: 0.9935 - val_loss: 1.2815 - val_accuracy: 0.7936
# Epoch 89/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 1.2996 - val_accuracy: 0.7900
# Epoch 90/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0218 - accuracy: 0.9934 - val_loss: 1.3247 - val_accuracy: 0.7861
# Epoch 91/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0208 - accuracy: 0.9932 - val_loss: 1.2965 - val_accuracy: 0.7951
# Epoch 92/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0201 - accuracy: 0.9940 - val_loss: 1.3110 - val_accuracy: 0.7913
# Epoch 93/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0192 - accuracy: 0.9932 - val_loss: 1.3057 - val_accuracy: 0.7936
# Epoch 94/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0245 - accuracy: 0.9933 - val_loss: 1.2878 - val_accuracy: 0.7946
# Epoch 95/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0215 - accuracy: 0.9932 - val_loss: 1.2913 - val_accuracy: 0.7931
# Epoch 96/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0174 - accuracy: 0.9944 - val_loss: 1.3064 - val_accuracy: 0.7943
# Epoch 97/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0174 - accuracy: 0.9946 - val_loss: 1.3096 - val_accuracy: 0.7932
# Epoch 98/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0184 - accuracy: 0.9943 - val_loss: 1.3216 - val_accuracy: 0.7934
# Epoch 99/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0206 - accuracy: 0.9934 - val_loss: 1.3178 - val_accuracy: 0.7941
# Epoch 100/100
# 212/212 [==============================] - 2s 9ms/step - loss: 0.0188 - accuracy: 0.9941 - val_loss: 1.3274 - val_accuracy: 0.7948

# %%
print("Training time:---  %s seconds ---" % (time.time() - start_time))
#Test the model after training
start_time=time.time()
test_results = model.evaluate(X_test, Y_test, verbose=1)
print(test_results)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]}%')
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Training time:---  185.3746566772461 seconds ---
# 310/310 [==============================] - 0s 1ms/step - loss: 1.2861 - accuracy: 0.7991
# [1.2861411571502686, 0.7990909218788147]
# Test results - Loss: 1.2861411571502686 - Accuracy: 0.7990909218788147%
# --- 0.6294963359832764 seconds ---
